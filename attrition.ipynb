# %% [markdown]
# <a href="https://colab.research.google.com/github/edoucet-AI/neural-network-challenge-2/blob/main/attrition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras import layers

#  Import and read the attrition data
attrition_df = pd.read_csv('https://static.bc-edx.com/ai/ail-v-1-0/m19/lms/datasets/attrition.csv')
attrition_df.head(10)
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   41       Yes      Travel_Rarely                   Sales                 1
# 1   49        No  Travel_Frequently  Research & Development                 8
# 2   37       Yes      Travel_Rarely  Research & Development                 2
# 3   33        No  Travel_Frequently  Research & Development                 3
# 4   27        No      Travel_Rarely  Research & Development                 2
# 5   32        No  Travel_Frequently  Research & Development                 2
# 6   59        No      Travel_Rarely  Research & Development                 3
# 7   30        No      Travel_Rarely  Research & Development                24
# 8   38        No  Travel_Frequently  Research & Development                23
# 9   36        No      Travel_Rarely  Research & Development                27
#
#    Education EducationField  EnvironmentSatisfaction  HourlyRate  \
# ...

# %%
# Determine the number of unique values in each column.
attrition_df.nunique()
# Out:
# Age                         43
# Attrition                    2
# BusinessTravel               3
# Department                   3
# DistanceFromHome            29
# Education                    5
# EducationField               6
# EnvironmentSatisfaction      4
# HourlyRate                  71
# JobInvolvement               4
# JobLevel                     5
# JobRole                      9
# JobSatisfaction              4
# MaritalStatus                3
# NumCompaniesWorked          10
# OverTime                     2
# PercentSalaryHike           15
# PerformanceRating            2
# RelationshipSatisfaction     4
# StockOptionLevel             4
# TotalWorkingYears           40
# TrainingTimesLastYear        7
# WorkLifeBalance              4
# YearsAtCompany              37
# YearsInCurrentRole          19
# YearsSinceLastPromotion     16
# YearsWithCurrManager        18
# dtype: int64

# %%
# Create y_df with the Attrition and Department columns
y_df = attrition_df[['Attrition', 'Department']]
y_df.head()
# Out:
#   Attrition              Department
# 0       Yes                   Sales
# 1        No  Research & Development
# 2       Yes  Research & Development
# 3        No  Research & Development
# 4        No  Research & Development

# %%
# Create a list of at least 10 column names to use as X data
selected_columns = ['Age', 'DistanceFromHome', 'Education', 'EnvironmentSatisfaction', 'RelationshipSatisfaction', 'HourlyRate', 'JobSatisfaction', 'JobInvolvement', 'YearsAtCompany', 'WorkLifeBalance']


# Create X_df using your selected columns
X_df = attrition_df[selected_columns]
X_df.head()
# Out:
#    Age  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41                 1          2                        2
# 1   49                 8          1                        3
# 2   37                 2          2                        4
# 3   33                 3          4                        4
# 4   27                 2          1                        1
#
#    RelationshipSatisfaction  HourlyRate  JobSatisfaction  JobInvolvement  \
# 0                         1          94                4               3
# 1                         4          61                2               2
# 2                         2          92                3               2
# 3                         3          56                3               3
# 4                         4          40                2               3
#
#    YearsAtCompany  WorkLifeBalance
# 0               6                1
# 1              10                3
# 2               0                3
# ...

# %%
# Show the data types for X_df
X_df.dtypes
# Out:
# Age                         int64
# DistanceFromHome            int64
# Education                   int64
# EnvironmentSatisfaction     int64
# RelationshipSatisfaction    int64
# HourlyRate                  int64
# JobSatisfaction             int64
# JobInvolvement              int64
# YearsAtCompany              int64
# WorkLifeBalance             int64
# dtype: object

# %%
from re import X
# Split the data into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_df, y_df, random_state=78)

# %%
# Convert your X data to numeric data types however you see fit
# Add new code cells as necessary

# %%
# Create a StandardScaler
scaler = StandardScaler()


# Fit the StandardScaler to the training data
X_scaler = scaler.fit(X_train)


# Scale the training and testing data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a OneHotEncoder for the Department column
from sklearn.preprocessing import OneHotEncoder
Dept_enc = OneHotEncoder(sparse_output=False)


# Fit the encoder to the training data
Dept_enc.fit(np.array(y_train['Department']).reshape(-1, 1))


# Create two new variables by applying the encoder
# to the training and testing data
y_train_department_encoded = Dept_enc.transform(np.array(y_train['Department']).reshape(-1, 1))
y_test_department_encoded = Dept_enc.transform(np.array(y_test['Department']).reshape(-1, 1))

#display values in array
y_train_department_encoded
# Out:
# array([[0., 0., 1.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [0., 1., 0.],
#        [0., 0., 1.],
#        [0., 1., 0.]])

# %%
# Create a OneHotEncoder for the Attrition column
Att_enc = OneHotEncoder(sparse_output=False)


# Fit the encoder to the training data
Att_enc.fit(np.array(y_train['Attrition']).reshape(-1, 1))


# Create two new variables by applying the encoder
# to the training and testing data
y_train_attrition_encoded = Att_enc.transform(np.array(y_train['Attrition']).reshape(-1, 1))
y_test_attrition_encoded = Att_enc.transform(np.array(y_test['Attrition']).reshape(-1, 1))

#display values in array
y_train_attrition_encoded
# Out:
# array([[0., 1.],
#        [1., 0.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [0., 1.]])

# %% [markdown]
# ## Create, Compile, and Train the Model

# %%
# Find the number of columns in the X training data
number_input_features = len(X_train.columns)
number_input_features


# Create the input layer
input = layers.Input(shape=(number_input_features,),name='input')

# Create at least two shared layers
shared1 = layers.Dense(units=64, activation='relu',name='shared1')(input)
shared2 = layers.Dense(units=128, activation='relu',name='shared2')(shared1)

# %%
# Create a branch for Department
# with a hidden layer and an output layer
# name the hidden layers department_hidden

# Create the hidden layer
department_hidden = layers.Dense(units=32, activation='relu',name='department_hidden')(shared2)

# Create the output layer
# name of output layer department_output
department_output = layers.Dense(y_train_department_encoded.shape[1], activation='sigmoid',name='department_output')(department_hidden)

# %%
# Create a branch for Attrition
# with a hidden layer and an output layer
# name the hidden layers attrition_hidden

# Create the hidden layer
attrition_hidden = layers.Dense(units=32, activation='relu',name='attrition_hidden')(shared2)


# Create the output layer
attrition_output = layers.Dense(y_train_attrition_encoded.shape[1], activation='sigmoid',name='attrition_output')(attrition_hidden)

# %%
# Create the model
model = Model(inputs=input, outputs={'department_output': department_output, 'attrition_output': attrition_output})


# Compile the model
model.compile(optimizer='adam',
              loss={
                  'department_output': 'categorical_crossentropy',
                  'attrition_output': 'binary_crossentropy'
              },
              metrics={
                  'department_output': 'accuracy',
                  'attrition_output': 'accuracy'
              })


# Summarize the model
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 10)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ shared1 (Dense)           │ (None, 64)             │            704 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ shared2 (Dense)           │ (None, 128)            │          8,320 │ shared1[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# ...

# %%
# Train the model
fit_model = model.fit(X_train_scaled, {'department_output': y_train_department_encoded, 'attrition_output': y_train_attrition_encoded}, epochs=100)
# Out:
# Epoch 1/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 1.0000 - attrition_output_loss: 3.8435e-08 - department_output_accuracy: 1.0000 - department_output_loss: 7.9558e-08 - loss: 1.1803e-07
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 1.0000 - attrition_output_loss: 3.5701e-08 - department_output_accuracy: 1.0000 - department_output_loss: 6.6987e-08 - loss: 1.0272e-07
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 1.0000 - attrition_output_loss: 3.9293e-08 - department_output_accuracy: 1.0000 - department_output_loss: 6.9955e-08 - loss: 1.0925e-07
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 1.0000 - attrition_output_loss: 3.6739e-08 - department_output_accuracy: 1.0000 - department_output_loss: 7.2316e-08 - loss: 1.0906e-07
# Epoch 5/100
# ...

# %%
# Evaluate the model with the testing data
evaluation_results = model.evaluate(X_test_scaled, {'department_output': y_test_department_encoded, 'attrition_output': y_test_attrition_encoded})
print("Evaluation results:", evaluation_results)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - attrition_output_accuracy: 0.8538 - attrition_output_loss: 4.4285 - department_output_accuracy: 0.5154 - department_output_loss: 11.2723 - loss: 15.7032
# Evaluation results: [15.002732276916504, 4.215365886688232, 10.772122383117676, 0.85326087474823, 0.5163043737411499]

# %%
# Print the accuracy for both department and attrition
department_accuracy = evaluation_results[4]
attrition_accuracy = evaluation_results[3]
print(f"Department Accuracy: {department_accuracy}")
print(f"Attrition Accuracy: {attrition_accuracy}")
# Out:
# Department Accuracy: 0.5163043737411499
# Attrition Accuracy: 0.85326087474823

# %% [markdown]
# # Summary
#
# In the provided space below, briefly answer the following questions.
#
# 1. Is accuracy the best metric to use on this data? Why or why not?
#
# 2. What activation functions did you choose for your output layers, and why?
#
# 3. Can you name a few ways that this model might be improved?

# %% [markdown]
# YOUR ANSWERS HERE
#
# 1. Accuracy was a good metric for this data because the dataset was relatively balanced.  Because the data was balanced accuracy provided a good overall measure of how well the model is performing.
# 2. I choose the Sigmoid activation function for my output layers because I needed to output range of probability value between 0 and 1. A common use case for the Sigmoid activation function is when the model needs to classify between two classes.  The Sigmoid outpuut represents the probablity of belonging to one of the classes.
# 3. A few ways I could improve the model is through hyperparameter tuning.  The number of hidden layers and units could be adjusted.  Adding and removing layers and changing the number of units in each layer may result in model improvement. One other way my model may be improved is by exploring different features to use in the model.  I only selecte 10 however there were many other options that might have been more informative for my model.
